# %%
import numpy as np
import matplotlib.pyplot as plt
from sentence_transformers import SentenceTransformer
from sklearn.preprocessing import normalize
import hdbscan
import umap

# %%
# reading in the words.txt
with open('../words.txt', 'r') as f:
    words = f.read().splitlines()

# convert to numpy array
words = np.array(words)
words
# Out:
# array(['birds', 'fuel', 'hammer', 'macabre', 'pray', 'unruly', 'blood',
#        'identify', 'opposite', 'erect', 'battle', 'public', 'concern',
#        'develop', 'placid', 'surround', 'cart', 'burly', 'empty',
#        'bite-sized', 'imaginary', 'zippy', 'tour', 'plate', 'terrible',
#        'regular', 'volleyball', 'chemical', 'flaky', 'sophisticated',
#        'innate', 'wobble', 'pushy', 'superb', 'truck', 'gainful', 'false',
#        'reaction', 'jam', 'tank', 'telling', 'rhetorical', 'encourage',
#        'peck', 'meddle', 'sudden', 'offbeat', 'paltry', 'grumpy',
#        'entertaining', 'paste', 'cheerful', 'sail', 'exist', 'experience',
#        'nod', 'pretty', 'delight', 'wrench', 'neck', 'sable',
#        'scientific', 'creator', 'chess', 'general', 'discover', 'selfish',
#        'foregoing', 'neat', 'stiff', 'waiting', 'children', 'sort',
#        'horse', 'kick', 'rock', 'type', 'hissing', 'harass', 'announce',
#        'boat', 'rich', 'birth', 'young', 'vest', 'lush', 'hang', 'letter',
#        'unwieldy', 'amazing', 'extend', 'fix', 'testy', 'arrest',
#        'hellish', 'dam', 'telephone', 'describe', 'jobless', 'ragged',
#        'past', 'rose', 'stone', 'terrify', 'stupendous', 'visitor',
#        'ill-fated', 'basin', 'spark', 'wasteful', 'wood', 'observant',
#        'historical', 'ink', 'command', 'tenuous', 'heal', 'heavenly',
#        'omniscient', 'tent', 'bent', 'inquisitive', 'vanish', 'verdant',
#        'zebra', 'rob', 'moon', 'blushing', 'lackadaisical', 'husky',
#        'place', 'alive', 'live', 'disapprove', 'nosy', 'pet', 'gaudy',
#        'volatile', 'crib', 'spotless', 'obsequious', 'call', 'lucky',
#        'awesome', 'spill', 'sock', 'boot', 'relation', 'mysterious',
#        'silver', 'repulsive', 'pedal', 'envious', 'bright', 'ultra',
#        'impartial', 'mark', 'available', 'porter', 'wrestle', 'tight',
#        'yummy', 'tacit', 'feeble', 'birthday', 'squeamish', 'first',
#        'nation', 'magic', 'careless', 'meal', 'fierce', 'useless', 'bike',
#        'sneeze', 'homeless', 'picture', 'therapeutic', 'salt',
#        'divergent', 'ripe', 'left', 'note', 'mass', 'repair', 'account',
#        'daffy', 'adjustment', 'hurry', 'abaft', 'crooked', 'disgusted',
#        'store', 'military', 'wrap', 'gather', 'temper', 'hop', 'protect',
#        'smelly', 'park', 'trust', 'mask', 'soggy', 'oil', 'grieving',
#        'look', 'acceptable', 'scold', 'whine', 'tidy', 'fixed', 'gamy',
#        'nail', 'bag', 'dust', 'glamorous', 'zipper', 'scintillating',
#        'walk', 'snails', 'dramatic', 'money', 'misty', 'slip', 'rural',
#        'womanly', 'earthy', 'aquatic', 'digestion', 'nimble', 'deeply',
#        'destruction', 'scrub', 'bashful', 'imperfect', 'unite',
#        'ludicrous', 'tumble', 'vigorous', 'tense', 'spell', 'broad',
#        'uncle', 'advice', 'reason', 'dull', 'bubble', 'flawless',
#        'reject', 'ticket', 'wild', 'legs', 'lavish', 'wiggly', 'weight',
#        'desert', 'listen', 'hydrant', 'stove', 'tickle', 'tip', 'fail',
#        'lip', 'curious', 'chase', 'disastrous', 'slope', 'ground',
#        'entertain', 'continue', 'imminent', 'branch', 'jumpy', 'tasty',
#        'mixed', 'protective', 'meeting', 'stocking', 'bleach', 'nine',
#        'roomy', 'leg', 'mist', 'moan', 'ruthless', 'toad', 'bedroom',
#        'unequaled', 'sin', 'far', 'deceive', 'next', 'division',
#        'efficient', 'join', 'decide', 'disarm', 'natural', 'plantation'],
#       dtype='<U13')

# %%
len(words)
# Out:
# 300

# %%
# encode vectors
model = SentenceTransformer('all-MiniLM-L6-v2')
embeddings = model.encode(words, show_progress_bar=True)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# C:\Users\lukas\Documents\AI4100\CS4100-Project\venv\Lib\site-packages\huggingface_hub\file_download.py:129: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\lukas\.cache\huggingface\hub\models--sentence-transformers--all-MiniLM-L6-v2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/10 [00:00<?, ?it/s]

# %%
# normalize the embeddings
embeddings = normalize(embeddings)

# %%
# run HDBSCAN
clusterer = hdbscan.HDBSCAN(min_cluster_size=5, min_samples=1, metric='euclidean')
cluster_labels = clusterer.fit_predict(embeddings)

# %%
from collections import defaultdict

clusters = defaultdict(list)

for i in range(len(words)):
    label = cluster_labels[i]
    # if it's noise (-1) ignore
    if label == -1:
        continue
    clusters[label].append(words[i])

# %%
# visualize with umap
reducer = umap.UMAP(n_neighbors=15, min_dist=0.1, metric='euclidean')
embedding_2d = reducer.fit_transform(embeddings)
plt.figure(figsize=(10, 10))
scatter = plt.scatter(embedding_2d[:, 0], embedding_2d[:, 1], c=cluster_labels, cmap='Spectral', s=50)
handles, labels = scatter.legend_elements()
plt.legend(handles, labels, title="Clusters")
plt.title('UMAP projection of the word embeddings')
plt.show()

# %%
from wordcloud import WordCloud

probs = clusterer.probabilities_

# only first 5 clusters
cluster_ids = list(clusters.keys())[:5]

# for each cluster id, make the word cloud
for cid in cluster_ids:
    freqs = {}

    for i in range(len(words)):
        if cluster_labels[i] != cid:
            continue
            # weighing based on freq
        freqs[words[i]] = probs[i]

    wc = WordCloud(width=600, height=400, background_color="white")
    wc = wc.generate_from_frequencies(freqs)

    plt.figure()
    plt.imshow(wc)
    plt.axis("off")
    plt.title(f"Cluster {cid}")
    plt.show()

# %%
# !pip install pandas
import pandas as pd
# Find the maximum length
max_len = max(len(v) for v in clusters.values())

# Pad shorter lists with NaN
for key in clusters:
    if len(clusters[key]) < max_len:
        clusters[key] += [np.nan] * (max_len - len(clusters[key]))

cluster_df = pd.DataFrame(clusters)
cluster_df.to_pickle("../cluster.pkl")
# Out:
# Requirement already satisfied: pandas in c:\users\lukas\documents\ai4100\cs4100-project\venv\lib\site-packages (3.0.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\lukas\documents\ai4100\cs4100-project\venv\lib\site-packages (from pandas) (2.4.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lukas\documents\ai4100\cs4100-project\venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\lukas\documents\ai4100\cs4100-project\venv\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\lukas\documents\ai4100\cs4100-project\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 4
#       1 get_ipython().system('pip install pandas')
#       2 import pandas as pd
#       3 # Find the maximum length
# ----> 4 max_len = max(len(v) for v in data.values())
#       5
#       6 # Pad shorter lists with NaN
#       7 for key in data:
#
# NameError: name 'data' is not defined

# %%
clusters
# Out:
# defaultdict(list,
#             {np.int64(7): [np.str_('fuel'),
#               np.str_('chemical'),
#               np.str_('truck'),
#               np.str_('reaction'),
#               np.str_('tank'),
#               np.str_('sail'),
#               np.str_('scientific'),
#               np.str_('boat'),
#               np.str_('pedal'),
#               np.str_('bike'),
#               np.str_('oil'),
#               np.str_('aquatic'),
#               np.str_('stove')],
#              np.int64(5): [np.str_('hammer'),
#               np.str_('plate'),
#               np.str_('wrench'),
#               np.str_('spill'),
#               np.str_('porter'),
#               np.str_('meal'),
#               np.str_('nail'),
#               np.str_('digestion'),
#               np.str_('tumble'),
#               np.str_('bubble'),
#               np.str_('tip')],
#              np.int64(0): [np.str_('pray'),
#               np.str_('fix'),
#               np.str_('heal'),
#               np.str_('therapeutic'),
#               np.str_('repair'),
#               np.str_('fixed'),
#               np.str_('scrub'),
#               np.str_('listen')],
#              np.int64(14): [np.str_('unruly'),
#               np.str_('stiff'),
#               np.str_('unwieldy'),
#               np.str_('ragged'),
#               np.str_('bent'),
#               np.str_('tight'),
#               np.str_('crooked'),
#               np.str_('womanly')],
#              np.int64(13): [np.str_('concern'),
#               np.str_('terrible'),
#               np.str_('wasteful'),
#               np.str_('careless'),
#               np.str_('fierce'),
#               np.str_('destruction'),
#               np.str_('imperfect'),
#               np.str_('disastrous'),
#               np.str_('ruthless'),
#               np.str_('efficient')],
#              np.int64(1): [np.str_('develop'),
#               np.str_('creator'),
#               np.str_('children'),
#               np.str_('birth'),
#               np.str_('young'),
#               np.str_('birthday')],
#              np.int64(6): [np.str_('zippy'),
#               np.str_('vest'),
#               np.str_('tent'),
#               np.str_('sneeze'),
#               np.str_('salt'),
#               np.str_('mask'),
#               np.str_('bag'),
#               np.str_('dust'),
#               np.str_('zipper')],
#              np.int64(4): [np.str_('regular'),
#               np.str_('innate'),
#               np.str_('type'),
#               np.str_('ultra'),
#               np.str_('wild'),
#               np.str_('natural')],
#              np.int64(10): [np.str_('pushy'),
#               np.str_('grumpy'),
#               np.str_('rock'),
#               np.str_('testy'),
#               np.str_('stone'),
#               np.str_('moon'),
#               np.str_('place'),
#               np.str_('nosy'),
#               np.str_('hop'),
#               np.str_('smelly'),
#               np.str_('park'),
#               np.str_('grieving'),
#               np.str_('walk'),
#               np.str_('earthy'),
#               np.str_('jumpy'),
#               np.str_('roomy'),
#               np.str_('bedroom')],
#              np.int64(12): [np.str_('superb'),
#               np.str_('pretty'),
#               np.str_('neat'),
#               np.str_('amazing'),
#               np.str_('blushing'),
#               np.str_('awesome'),
#               np.str_('bright'),
#               np.str_('flawless'),
#               np.str_('curious')],
#              np.int64(11): [np.str_('cheerful'),
#               np.str_('delight'),
#               np.str_('hellish'),
#               np.str_('heavenly'),
#               np.str_('yummy'),
#               np.str_('tacit'),
#               np.str_('tasty')],
#              np.int64(2): [np.str_('exist'),
#               np.str_('telephone'),
#               np.str_('alive'),
#               np.str_('live'),
#               np.str_('call'),
#               np.str_('reject'),
#               np.str_('decide')],
#              np.int64(9): [np.str_('waiting'),
#               np.str_('hang'),
#               np.str_('available'),
#               np.str_('hurry'),
#               np.str_('fail'),
#               np.str_('continue')],
#              np.int64(3): [np.str_('kick'),
#               np.str_('wood'),
#               np.str_('sock'),
#               np.str_('boot'),
#               np.str_('legs'),
#               np.str_('leg'),
#               np.str_('plantation')],
#              np.int64(8): [np.str_('rich'),
#               np.str_('letter'),
#               np.str_('magic'),
#               np.str_('money'),
#               np.str_('spell'),
#               np.str_('lavish')]})
